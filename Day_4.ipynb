# %% [raw]
# ✅ Day 4: Handling Missing Values & Grouping Data in Pandas

# %% [markdown]
# # 📅 Day 4: Clean & Organize Data with Pandas
#
# Welcome to Day 4 of the 45-day Data Science with AI Challenge! 🙌
#
# Today’s focus:
# 1. 🧼 How to handle **missing values** in real datasets
# 2. 📊 How to group and summarize data using **groupby()**
#
# Let’s dive in!

# %% [markdown]
# 🧼 Part 1: Handling Missing Values (Part 2)

# %%
# Step 1: Import pandas and numpy
import pandas as pd
import numpy as np

# Step 2: Load the Railway dataset
railway = pd.read_csv("Railway Ticket Confirmation.csv")
railway.head()
# Out:
#       PNR Number  Train Number Date of Journey Class of Travel  \
# 0  PNR0000000000         51450      2024-09-01             3AC
# 1  PNR0000000001         54807      2024-09-02             3AC
# 2  PNR0000000002         14396      2024-09-03             3AC
# 3  PNR0000000003         20295      2024-09-04             3AC
# 4  PNR0000000004         48598      2024-09-05             2AC
#
#             Quota Source Station Destination Station Booking Date  \
# 0         General           NDLS                CSMT   2024-01-01
# 1  Premium Tatkal           MMCT                 LTT   2024-01-02
# 2          Ladies            GKP                 BBS   2024-01-03
# 3          Ladies            ASR                KOAA   2024-01-04
# 4          Tatkal            MAS                 SBC   2024-01-05
#
#   Current Status  Number of Passengers  ... Booking Channel Travel Distance  \
# 0      Confirmed                     4  ...         Counter            1656
# 1     Waitlisted                     5  ...      Mobile App            1932
# 2            RAC                     5  ...   IRCTC Website             155
# 3     Waitlisted                     1  ...         Counter            1840
# 4      Confirmed                     3  ...      Mobile App            1766
#
#    Number of Stations  Travel Time  Train Type Seat Availability  \
# 0                  17           37    Shatabdi               159
# 1                  18            6    Shatabdi               309
# 2                   4           17     Express               143
# 3                   5           16   Superfast               256
# 4                   9           32     Express                58
#
#    Special Considerations Holiday or Peak Season Waitlist Position  \
# 0          Senior Citizen                    Yes               NaN
# 1                    None                    Yes             WL097
# 2                    None                    Yes               NaN
# 3          Senior Citizen                     No             WL011
# 4                    None                    Yes               NaN
#
#   Confirmation Status
# 0           Confirmed
# 1       Not Confirmed
# 2           Confirmed
# 3       Not Confirmed
# 4           Confirmed
#
# [5 rows x 21 columns]

# %% [markdown]
# 🔍 Check for Missing Data

# %%
# Get info about each column
railway.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   PNR Number              30000 non-null  object
#  1   Train Number            30000 non-null  int64
#  2   Date of Journey         30000 non-null  object
#  3   Class of Travel         30000 non-null  object
#  4   Quota                   30000 non-null  object
#  5   Source Station          30000 non-null  object
#  6   Destination Station     30000 non-null  object
#  7   Booking Date            30000 non-null  object
#  8   Current Status          30000 non-null  object
#  9   Number of Passengers    30000 non-null  int64
#  10  Age of Passengers       30000 non-null  object
#  11  Booking Channel         30000 non-null  object
#  12  Travel Distance         30000 non-null  int64
#  13  Number of Stations      30000 non-null  int64
#  14  Travel Time             30000 non-null  int64
#  15  Train Type              30000 non-null  object
#  16  Seat Availability       30000 non-null  int64
#  17  Special Considerations  30000 non-null  object
#  18  Holiday or Peak Season  30000 non-null  object
#  19  Waitlist Position       10053 non-null  object
#  20  Confirmation Status     30000 non-null  object
# dtypes: int64(6), object(15)
# memory usage: 4.8+ MB

# %%
# Check where data is missing (True = missing)
railway.isna().head()
# Out:
#    PNR Number  Train Number  Date of Journey  Class of Travel  Quota  \
# 0       False         False            False            False  False
# 1       False         False            False            False  False
# 2       False         False            False            False  False
# 3       False         False            False            False  False
# 4       False         False            False            False  False
#
#    Source Station  Destination Station  Booking Date  Current Status  \
# 0           False                False         False           False
# 1           False                False         False           False
# 2           False                False         False           False
# 3           False                False         False           False
# 4           False                False         False           False
#
#    Number of Passengers  ...  Booking Channel  Travel Distance  \
# 0                 False  ...            False            False
# 1                 False  ...            False            False
# 2                 False  ...            False            False
# 3                 False  ...            False            False
# 4                 False  ...            False            False
#
#    Number of Stations  Travel Time  Train Type  Seat Availability  \
# 0               False        False       False              False
# 1               False        False       False              False
# 2               False        False       False              False
# 3               False        False       False              False
# 4               False        False       False              False
#
#    Special Considerations  Holiday or Peak Season  Waitlist Position  \
# 0                   False                   False               True
# 1                   False                   False              False
# 2                   False                   False               True
# 3                   False                   False              False
# 4                   False                   False               True
#
#    Confirmation Status
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
#
# [5 rows x 21 columns]

# %%
# Count missing values in each column
railway.isna().sum()
# Out:
# PNR Number                    0
# Train Number                  0
# Date of Journey               0
# Class of Travel               0
# Quota                         0
# Source Station                0
# Destination Station           0
# Booking Date                  0
# Current Status                0
# Number of Passengers          0
# Age of Passengers             0
# Booking Channel               0
# Travel Distance               0
# Number of Stations            0
# Travel Time                   0
# Train Type                    0
# Seat Availability             0
# Special Considerations        0
# Holiday or Peak Season        0
# Waitlist Position         19947
# Confirmation Status           0
# dtype: int64

# %% [raw]
# ✅ Option 1: Drop Missing Data

# %%
# Drop rows where any data is missing
railway_cleaned = railway.dropna()
railway_cleaned.head()
# Out:
#        PNR Number  Train Number Date of Journey Class of Travel  \
# 1   PNR0000000001         54807      2024-09-02             3AC
# 3   PNR0000000003         20295      2024-09-04             3AC
# 10  PNR0000000010         84954      2024-09-11             1AC
# 17  PNR0000000017         17913      2024-09-18             2AC
# 18  PNR0000000018         15855      2024-09-19             3AC
#
#              Quota Source Station Destination Station Booking Date  \
# 1   Premium Tatkal           MMCT                 LTT   2024-01-02
# 3           Ladies            ASR                KOAA   2024-01-04
# 10          Tatkal            CNB                 MAS   2024-01-11
# 17          Ladies            JHS                  JP   2024-01-18
# 18         General            JHS                 HWH   2024-01-19
#
#    Current Status  Number of Passengers  ... Booking Channel Travel Distance  \
# 1      Waitlisted                     5  ...      Mobile App            1932
# 3      Waitlisted                     1  ...         Counter            1840
# 10     Waitlisted                     4  ...         Counter            1830
# 17     Waitlisted                     3  ...      Mobile App            1038
# 18     Waitlisted                     3  ...      Mobile App             639
#
#     Number of Stations  Travel Time  Train Type Seat Availability  \
# 1                   18            6    Shatabdi               309
# 3                    5           16   Superfast               256
# 10                  11           46     Express               116
# 17                   3           47    Shatabdi               162
# 18                  17           24    Rajdhani               162
#
#     Special Considerations Holiday or Peak Season Waitlist Position  \
# 1                     None                    Yes             WL097
# 3           Senior Citizen                     No             WL011
# 10           Defense Quota                    Yes             WL065
# 17           Defense Quota                     No             WL026
# 18          Senior Citizen                     No             WL086
#
#    Confirmation Status
# 1        Not Confirmed
# 3        Not Confirmed
# 10       Not Confirmed
# 17       Not Confirmed
# 18       Not Confirmed
#
# [5 rows x 21 columns]

# %%
railway_cleaned.shape
# Out:
# (10053, 21)

# %% [raw]
# ✅ Option 2: Fill Missing Data

# %%
# Fill missing values with a specific value
railway_cleaned = railway_cleaned.copy()
railway_cleaned['Waitlist Position'].fillna(mode_value, inplace=True)

# Confirm there are no more missing values
railway_cleaned.isna().sum()
# Out:
# PNR Number                0
# Train Number              0
# Date of Journey           0
# Class of Travel           0
# Quota                     0
# Source Station            0
# Destination Station       0
# Booking Date              0
# Current Status            0
# Number of Passengers      0
# Age of Passengers         0
# Booking Channel           0
# Travel Distance           0
# Number of Stations        0
# Travel Time               0
# Train Type                0
# Seat Availability         0
# Special Considerations    0
# Holiday or Peak Season    0
# Waitlist Position         0
# Confirmation Status       0
# Waitlist Numeric          0
# dtype: int64

# %% [markdown]
# 📊 Part 2: Grouping Data with groupby()

# %% [markdown]
# Pandas `groupby()` is used to **split** data into groups, **apply** a function, and then **combine** the result.
#
# Think of it like making summaries:
# - What's the average age of passengers in each class?
# - How many survived in each gender?

# %%
 #Use a different method of aggregation suitable for categorical data, such as .count() or .value_counts().
railway_cleaned.groupby('Class of Travel')['Age of Passengers'].value_counts()
# Out:
# Class of Travel  Age of Passengers
# 1AC              Adult                877
#                  Child                835
#                  Senior Citizen       793
# 2AC              Child                844
#                  Senior Citizen       833
#                  Adult                820
# 3AC              Child                833
#                  Adult                816
#                  Senior Citizen       816
# Sleeper          Senior Citizen       903
#                  Child                852
#                  Adult                831
# Name: Age of Passengers, dtype: int64

# %%
# Count number of people in each class
railway_cleaned.groupby('Class of Travel')['Age of Passengers'].count()
# Out:
# Class of Travel
# 1AC        2505
# 2AC        2497
# 3AC        2465
# Sleeper    2586
# Name: Age of Passengers, dtype: int64

# %%
# Group by both 'Pclass' and 'Sex'
railway_cleaned.groupby(['Class of Travel', 'Source Station', 'Destination Station']).size()
# Out:
# Class of Travel  Source Station  Destination Station
# 1AC              ADI             ADI                    5
#                                  ASR                    4
#                                  BBS                    6
#                                  BCT                    7
#                                  BSB                    2
#                                                        ..
# Sleeper          UMB             NJP                    7
#                                  PNBE                   5
#                                  SBC                    7
#                                  SC                     7
#                                  UMB                    6
# Length: 2094, dtype: int64

# %% [markdown]
# ✅ Summary
#
#     ✅ You learned how to check, drop, and fill missing data
#
#     📊 You grouped and summarized data using groupby()
#
#     These are essential steps in cleaning and exploring any dataset

# %% [markdown]
# 🎉 That’s a wrap on Day 4!
#
# 📌 Tomorrow we’ll learn how to merge and join multiple datasets in Pandas.
#
# 👉 Stay consistent and keep sharing your progress with #45DaysOfDataScience!
